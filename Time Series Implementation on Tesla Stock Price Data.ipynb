# %% [markdown]
# 1. Data Ingestion
# 2. EDA of the data
# 3. Processing of the data
# 4. Model Building
# 5. Model Evaluation

# %% [markdown]
# ### Data Ingestion

# %% [markdown]
# - Import the Required Libraries: Import the required libraries such as pandas, numpy, matplotlib, seaborn, etc.
#
# - Load the Data.
#
# - Load the Time Series Data into a pandas dataframe.
#
# - Set the datetime column as the index of the dataframe.
#
# - Check the datatype of the index and convert it to datetime if necessary.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
# Load Tesla Stock Price Data

data=pd.read_csv("C:\\Users\\Yash\\TSLA.CSV")
data
# Out:
#            Date        Open        High         Low       Close     Volume  \
# 0    2019-05-21   39.551998   41.480000   39.208000   41.015999   90019500
# 1    2019-05-22   39.820000   40.787998   38.355999   38.546001   93426000
# 2    2019-05-23   38.868000   39.894001   37.243999   39.098000  132735500
# 3    2019-05-24   39.966000   39.995998   37.750000   38.125999   70683000
# 4    2019-05-28   38.240002   39.000000   37.570000   37.740002   51564500
# ..          ...         ...         ...         ...         ...        ...
# 753  2022-05-16  767.159973  769.760010  719.090027  724.369995   28699500
# 754  2022-05-17  747.359985  764.479980  728.849976  761.609985   26745400
# 755  2022-05-18  744.520020  760.500000  700.809998  709.809998   29270600
# 756  2022-05-19  707.000000  734.000000  694.109985  709.419983   30098900
# 757  2022-05-20  713.989990  721.580017  633.000000  663.900024   48190600
#
#      Dividends  Stock Splits
# 0            0           0.0
# 1            0           0.0
# 2            0           0.0
# 3            0           0.0
# 4            0           0.0
# ..         ...           ...
# 753          0           0.0
# 754          0           0.0
# 755          0           0.0
# 756          0           0.0
# 757          0           0.0
#
# [758 rows x 8 columns]

# %%
# univariate analysis:

stock_data=data[['Date','Close']]
stock_data
# Out:
#            Date       Close
# 0    2019-05-21   41.015999
# 1    2019-05-22   38.546001
# 2    2019-05-23   39.098000
# 3    2019-05-24   38.125999
# 4    2019-05-28   37.740002
# ..          ...         ...
# 753  2022-05-16  724.369995
# 754  2022-05-17  761.609985
# 755  2022-05-18  709.809998
# 756  2022-05-19  709.419983
# 757  2022-05-20  663.900024
#
# [758 rows x 2 columns]

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    758 non-null    object
#  1   Close   758 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 12.0+ KB

# %% [markdown]
# we need to convert the datatype of Date column to date-time format

# %%
stock_data['Date']=pd.to_datetime(stock_data['Date'])
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_29560\3223040857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data['Date']=pd.to_datetime(stock_data['Date'])

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    758 non-null    datetime64[ns]
#  1   Close   758 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 12.0 KB

# %%
stock_data
# Out:
#           Date       Close
# 0   2019-05-21   41.015999
# 1   2019-05-22   38.546001
# 2   2019-05-23   39.098000
# 3   2019-05-24   38.125999
# 4   2019-05-28   37.740002
# ..         ...         ...
# 753 2022-05-16  724.369995
# 754 2022-05-17  761.609985
# 755 2022-05-18  709.809998
# 756 2022-05-19  709.419983
# 757 2022-05-20  663.900024
#
# [758 rows x 2 columns]

# %% [markdown]
#  we need to make Date col as index

# %%
stock_data.set_index("Date",inplace=True)

# %%
stock_data
# Out:
#                  Close
# Date
# 2019-05-21   41.015999
# 2019-05-22   38.546001
# 2019-05-23   39.098000
# 2019-05-24   38.125999
# 2019-05-28   37.740002
# ...                ...
# 2022-05-16  724.369995
# 2022-05-17  761.609985
# 2022-05-18  709.809998
# 2022-05-19  709.419983
# 2022-05-20  663.900024
#
# [758 rows x 1 columns]

# %% [markdown]
# ### EDA of the data

# %% [markdown]
# 1. Summary Statistics
# -   Compute summary statistics such as mean, median, mode, standard deviation, to get an overview of the data.
# 2. Visualize the Time Series Data
# - Plot the Time Series data
#
# - Plot the rolling mean and rolling standard deviation of the Time Series data.
#
# - Decompose the Time Series Data check for any trends, seasonality, and Noise.
#
# - Plot the decomposed components to get a better understanding of the Time Series data.
#
# 3. Stationarity Check
# - Check for stationarity.
# - Check for stationarity of the Time Series data using the Augmented Dickey-Fuller test.
#
# 4. Check for Autocorrelation
# - Plot the autocorrelation function (ACF) and partial autocorrelation function (PACF) to identify the order of the ARIMA model.
#
# 5. Outlier Detection
# - Detect and handle outliers using statistical methods or machine learning techniques.
#
# 6. Check for Autocorrelation
# - Plot the autocorrelation function (ACF) and partial autocorrelation function (PACF) to identify the order of the ARIMA model.

# %%
# summary stats:

stock_data.describe()
# Out:
#              Close
# count   758.000000
# mean    485.531513
# std     353.160353
# min      35.793999
# 25%     112.323500
# 50%     488.125000
# 75%     762.142502
# max    1229.910034

# %%
# plotting close price
plt.style.use('ggplot')
plt.figure(figsize=(18,8)) 
plt.grid(True) 
plt.xlabel('Dates', fontsize = 20) 
plt.xticks(fontsize = 15)
plt.ylabel('Close Prices', fontsize = 20)
plt.yticks(fontsize = 15) 
plt.plot(stock_data['Close'], linewidth = 3, color = 'blue')
plt.title('Tesla Stock Closing Price', fontsize = 30)
plt.show()

# %%
# plotting close price
plt.style.use('ggplot')
plt.figure(figsize=(18,8)) 
plt.grid(True) 
plt.xlabel('Dates', fontsize = 20) 
plt.xticks(fontsize = 15)
plt.ylabel('Close Prices', fontsize = 20)
plt.yticks(fontsize = 15) 
plt.hist(stock_data['Close'], linewidth = 3, color = 'blue')
plt.title('Tesla Stock Closing Price', fontsize = 30)
plt.show()

# %%
# Distribution of the close price  
df_close = stock_data['Close'] 
df_close.plot(kind='kde',figsize = (18,8), linewidth= 3) 
plt.xticks(fontsize = 15)
plt.grid("both")
plt.ylabel('Density', fontsize = 20)
plt.yticks(fontsize = 15)
plt.show()

# %%
roll_mean=stock_data['Close'].rolling(48).mean()
roll_mean
# Out:
# Date
# 2019-05-21           NaN
# 2019-05-22           NaN
# 2019-05-23           NaN
# 2019-05-24           NaN
# 2019-05-28           NaN
#                  ...
# 2022-05-16    936.968953
# 2022-05-17    934.940620
# 2022-05-18    932.263746
# 2022-05-19    930.473537
# 2022-05-20    928.338746
# Name: Close, Length: 758, dtype: float64

# %%
roll_std=stock_data['Close'].rolling(48).std()
roll_std
# Out:
# Date
# 2019-05-21           NaN
# 2019-05-22           NaN
# 2019-05-23           NaN
# 2019-05-24           NaN
# 2019-05-28           NaN
#                  ...
# 2022-05-16    113.126351
# 2022-05-17    115.404496
# 2022-05-18    119.124084
# 2022-05-19    121.840134
# 2022-05-20    125.615809
# Name: Close, Length: 758, dtype: float64

# %%
plt.figure(figsize=(10,10))
plt.plot(stock_data['Close'])
plt.plot(roll_mean,)
plt.plot(roll_std)

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\yash\.conda\envs\tensor2\lib\site-packages (0.14.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: pandas>=1.0 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from statsmodels) (1.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy>=1.18 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from statsmodels) (1.22.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from pandas>=1.0->statsmodels) (2022.1)
# Requirement already satisfied: six in c:\users\yash\.conda\envs\tensor2\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#ADF(ADA Fuller) Test

from statsmodels.tsa.stattools import adfuller
adft=adfuller(stock_data['Close'])

# %%
pd.Series(adft[:4],index=['test_stats','p-value','lag','data points'])
# Out:
# test_stats      -1.363009
# p-value          0.599876
# lag              9.000000
# data points    748.000000
# dtype: float64

# %% [markdown]
# Null Hypothesis:- Data is non stationary
#
# p-value=0.599876
#
# p-value<0.599876-> Reject Null Hypothesis <br>
# p-value>0.599876-> Accept Null Hypothesis

# %%
# test for stationary

def test_stationary(timeseries):
    rolmean=timeseries.rolling(48).mean() # rolling mean
    rolstd=timeseries.rolling(48).std() #rolling standard deviation
    #plot rolling stats:
    plt.figure(figsize = (18,8))
    plt.grid('both')
    plt.plot(timeseries, color='blue',label='Original', linewidth = 3)
    plt.plot(rolmean, color='red', label='Rolling Mean',linewidth = 3)
    plt.plot(rolstd, color='black', label = 'Rolling Std',linewidth = 4)
    plt.legend(loc='best', fontsize = 20, shadow=True,facecolor='lightpink',edgecolor = 'k')
    plt.title('Rolling Mean and Standard Deviation', fontsize = 25)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.show(block=False)
    
    print("Results of Dicker Fuller Test-->")
    print()
    adft=adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    # hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)

# %%
test_stationary(stock_data["Close"])
# Out:
# Results of Dicker Fuller Test-->
#
# Test Statistics                 -1.363009
# p-value                          0.599876
# No. of lags used                 9.000000
# Number of observations used    748.000000
# critical value (1%)             -3.439123
# critical value (5%)             -2.865412
# critical value (10%)            -2.568832
# dtype: float64

# %%
# outlier check

sns.boxplot(stock_data['Close'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# No Outliers in data

# %%
# time series decomposition

from statsmodels.tsa.seasonal import seasonal_decompose
result=seasonal_decompose(stock_data[['Close']],period=12)

# %%
fig=plt.figure(figsize=(20,10))
fig=result.plot()
fig.set_size_inches(17,10)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result=seasonal_decompose(stock_data[["Close"]],period=12,model="multiplicative")

# %%
fig=plt.figure(figsize=(20,10))
fig=result.plot()
fig.set_size_inches(17,10)

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(stock_data['Close'])
plot_pacf(stock_data['Close'])

# %% [markdown]
# ### Pre-processing of the data

# %% [markdown]
# 1. Fill the missing data.( not required here)
# 2. Convert Data into stationary time series.
# 3. If necessary then normalize the data.(not required here)
# 4. Split the data into train and test.
# 5. Clean the data by removing the outlier.(not required here)

# %%
stock_data.isna().sum()
# Out:
# Close    0
# dtype: int64

# %% [markdown]
# no missing data

# %%
# convert data stationary time series:
df_close=stock_data['Close']
df_close
# Out:
# Date
# 2019-05-21     41.015999
# 2019-05-22     38.546001
# 2019-05-23     39.098000
# 2019-05-24     38.125999
# 2019-05-28     37.740002
#                  ...
# 2022-05-16    724.369995
# 2022-05-17    761.609985
# 2022-05-18    709.809998
# 2022-05-19    709.419983
# 2022-05-20    663.900024
# Name: Close, Length: 758, dtype: float64

# %%
df_close=df_close.diff()
df_close=df_close.dropna()

# %%
test_stationary(df_close)
# Out:
# Results of Dicker Fuller Test-->
#
# Test Statistics               -8.324564e+00
# p-value                        3.498786e-13
# No. of lags used               8.000000e+00
# Number of observations used    7.480000e+02
# critical value (1%)           -3.439123e+00
# critical value (5%)           -2.865412e+00
# critical value (10%)          -2.568832e+00
# dtype: float64

# %%
# Splitting the data into test and train

df_close[0:-60]
# Out:
# Date
# 2019-05-22    -2.469997
# 2019-05-23     0.551998
# 2019-05-24    -0.972000
# 2019-05-28    -0.385998
# 2019-05-29     0.231998
#                 ...
# 2022-02-17   -47.040039
# 2022-02-18   -19.369995
# 2022-02-22   -35.449951
# 2022-02-23   -57.490051
# 2022-02-24    36.730042
# Name: Close, Length: 697, dtype: float64

# %%
df_close[-60:]
# Out:
# Date
# 2022-02-25      9.099976
# 2022-02-28     60.559998
# 2022-03-01     -6.059998
# 2022-03-02     15.520020
# 2022-03-03    -40.600037
# 2022-03-04     -1.000000
# 2022-03-07    -33.709961
# 2022-03-08     19.820007
# 2022-03-09     34.569946
# 2022-03-10    -20.669983
# 2022-03-11    -42.950012
# 2022-03-14    -28.979980
# 2022-03-15     35.520020
# 2022-03-16     38.339966
# 2022-03-17     31.369995
# 2022-03-18     33.790039
# 2022-03-21     15.769958
# 2022-03-22     72.820007
# 2022-03-23      5.130005
# 2022-03-24     14.809998
# 2022-03-25     -3.279968
# 2022-03-28     81.199951
# 2022-03-29      7.729980
# 2022-03-30     -5.579956
# 2022-03-31    -16.390015
# 2022-04-01      6.989990
# 2022-04-04     60.859985
# 2022-04-05    -54.189941
# 2022-04-06    -45.500000
# 2022-04-07     11.500000
# 2022-04-08    -31.770020
# 2022-04-11    -49.559998
# 2022-04-12     11.020020
# 2022-04-13     35.419983
# 2022-04-14    -37.369995
# 2022-04-18     19.289978
# 2022-04-19     23.860046
# 2022-04-20    -50.950012
# 2022-04-21     31.580017
# 2022-04-22     -3.730042
# 2022-04-25     -7.029968
# 2022-04-26   -121.600037
# 2022-04-27      5.090027
# 2022-04-28     -4.000000
# 2022-04-29     -6.750000
# 2022-05-02     32.179993
# 2022-05-03      6.309998
# 2022-05-04     43.369995
# 2022-05-05    -79.339966
# 2022-05-06     -7.630005
# 2022-05-09    -78.540039
# 2022-05-10     12.929993
# 2022-05-11    -66.039978
# 2022-05-12     -6.000000
# 2022-05-13     41.590027
# 2022-05-16    -45.220032
# 2022-05-17     37.239990
# 2022-05-18    -51.799988
# 2022-05-19     -0.390015
# 2022-05-20    -45.519958
# Name: Close, dtype: float64

# %%
##split data into training and testing set
train_data=df_close[:-60]
test_data=df_close[-60:]
plt.figure(figsize=(18,18))
plt.grid(True)
plt.xlabel('Dates',fontsize=20)
plt.ylabel('Closing',fontsize=20)
plt.xticks(fontsize=15)
plt.plot(train_data,'green',label='Train Data',linewidth=5)
plt.plot(test_data,'blue',label='Test Data',linewidth=5)
plt.legend(fontsize=20,shadow=True,facecolor='lightpink',edgecolor='k')

# %% [markdown]
# ### Model Building

# %%
len(stock_data['Close'])
# Out:
# 758

# %%
len(train_data)
# Out:
# 697

# %%
len(test_data)
# Out:
# 60

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
history=[ x for x in train_data]

# %%
model=ARIMA(history,order=(1,1,1))

# %%
model=model.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  697
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3148.870
# Date:                Sun, 28 May 2023   AIC                           6303.741
# Time:                        22:37:17   BIC                           6317.377
# Sample:                             0   HQIC                          6309.013
#                                 - 697
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0285      0.025     -1.150      0.250      -0.077       0.020
# ma.L1         -0.9991      0.012    -81.342      0.000      -1.023      -0.975
# sigma2       493.6006     12.978     38.035      0.000     468.165     519.036
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2092.37
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):              31.85   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model.forecast()[0]
# Out:
# 0.0474167150574516

# %%
mean_squared_error([test_data[0]],model.forecast())
# Out:
# 81.94882211074906

# %%
np.sqrt(mean_squared_error([test_data[0]],model.forecast()))
# Out:
# 9.052558870880048

# %%
def train_arima_model(X,y,arima_order):
    
    history=[x for x in X]
    predictions=list()
    for t in range(len(y)):
        model=ARIMA(history,order=arima_order)
        model_fit=model.fit()
        yhat=model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(y[t])
    rmse=np.sqrt(mean_squared_error(y,predictions))
    return rmse

# %%
def evaluate_models(dataset,test,p_vals,d_vals,q_vals):
    dataset=dataset.astype('float32')
    best_score,best_cfg=float('inf'),None
    
    for p in p_vals:
        for d in d_vals:
            for q in q_vals:
                order=(p,d,q)
                
                try:
                    rmse=train_arima_model(dataset,test,order)
                    
                    if rmse<best_score:
                        best_score,best_cfg=rmse,order
                    print("ARIMA%s RMSE=%.3f"%(order,rmse))
                    
                except:
                    continue
    print('Best Arima%s RMSE=%.3f'%(best_cfg,best_score))

# %%
import warnings
warnings.filterwarnings('ignore')
p_vals=range(0,3)
d_vals=range(0,3)
q_vals=range(0,3)

evaluate_models(train_data,test_data,p_vals,d_vals,q_vals)
# Out:
# ARIMA(0, 0, 0) RMSE=39.610
# ARIMA(0, 0, 1) RMSE=39.578
# ARIMA(0, 0, 2) RMSE=39.728
# ARIMA(0, 1, 0) RMSE=57.835
# ARIMA(0, 1, 1) RMSE=39.611
# ARIMA(0, 1, 2) RMSE=39.580
# ARIMA(0, 2, 0) RMSE=104.683
# ARIMA(0, 2, 1) RMSE=57.876
# ARIMA(0, 2, 2) RMSE=39.520
# ARIMA(1, 0, 0) RMSE=39.570
# ARIMA(1, 0, 1) RMSE=39.636
# ARIMA(1, 0, 2) RMSE=40.047
# ARIMA(1, 1, 0) RMSE=46.184
# ARIMA(1, 1, 1) RMSE=39.573
# ARIMA(1, 1, 2) RMSE=39.731
# ARIMA(1, 2, 0) RMSE=68.740
# ARIMA(1, 2, 1) RMSE=46.221
# ARIMA(1, 2, 2) RMSE=39.545
# ARIMA(2, 0, 0) RMSE=39.746
# ARIMA(2, 0, 1) RMSE=39.884
# ARIMA(2, 0, 2) RMSE=40.154
# ARIMA(2, 1, 0) RMSE=45.781
# ARIMA(2, 1, 1) RMSE=39.739
# ARIMA(2, 1, 2) RMSE=39.732
# ARIMA(2, 2, 0) RMSE=63.008
# ARIMA(2, 2, 1) RMSE=45.809
# Best Arima(0, 2, 2) RMSE=39.520

# %%
history = [x for x in train_data]
predictions = list()
for t in range(len(test_data)):
    model = ARIMA(history,order=(0,2,2))
    model_fit = model.fit()
    fc = model_fit.forecast(alpha = 0.05)
    predictions.append(fc)
    history.append(test_data[t])
print('RMSE of ARIMA Model:', np.sqrt(mean_squared_error(test_data, predictions)))
# Out:
# RMSE of ARIMA Model: 39.53366981907604

# %%
plt.figure(figsize=(18,8))
plt.grid(True)
plt.plot(range(len(test_data)),test_data, label = 'True Test Close Value', linewidth = 5)
plt.plot(range(len(predictions)), predictions, label = 'Predictions on test data', linewidth = 5)
plt.xticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.legend(fontsize = 20, shadow=True,facecolor='lightpink',edgecolor = 'k')
plt.show()

# %%
fc_series = pd.Series(predictions, index=test_data.index)

# %%
# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_data, label='Training', color = 'blue')
plt.plot(test_data, label='Test', color = 'green', linewidth = 3)
plt.plot(fc_series, label='Forecast', color = 'red')
plt.title('Forecast vs Actuals on test data')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_predict
fig = plt.figure(figsize=(18,8))
ax1 = fig.add_subplot(111)
plot_predict(result=model_fit,start=1, end=len(df_close)+60, ax = ax1)
plt.grid("both")
plt.legend(['Forecast','Close','95% confidence interval'],fontsize = 20, shadow=True,facecolor='lightblue',edgecolor = 'k')
plt.show()

# %%
# evaluate parameters
import warnings
warnings.filterwarnings('ignore')
history = [x for x in train_data]
predictions = list()
conf_list = list()
for t in range(len(test_data)):
    model = sm.tsa.statespace.SARIMAX(history, order = (0,1,0), seasonal_order = (1,1,1,3))
    model_fit = model.fit()
    fc = model_fit.forecast()
    predictions.append(fc)
    history.append(test_data[t])
print('RMSE of SARIMA Model:', np.sqrt(mean_squared_error(test_data, predictions)))
# Out:
# RMSE of SARIMA Model: 57.869252552804326

# %%
plt.figure(figsize=(18,8))
plt.title('Forecast vs Actual', fontsize = 25)
plt.plot(range(60), predictions, label = 'Predictions', linewidth = 4)
plt.plot(range(60), test_data, label = 'Close', linewidth = 4)
plt.legend(fontsize = 25, shadow=True,facecolor='lightpink',edgecolor = 'k')
